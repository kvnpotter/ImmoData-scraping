# %% [markdown]
# # Data cleanining
# ## Imports

# %%
# Import pandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load data in DataFrame

# %%
# Read data
data = pd.read_csv("Immoweb_scraping_result.csv")

# %% [markdown]
# ## Look at data

# %%
# First look
data.head()
# Out:
#          id  Locality Type of property Subtype of property   Price  \
# 0  20320744      1150        APARTMENT           APARTMENT  575000
# 1  20317718      9000        APARTMENT           APARTMENT  390000
# 2  20315842      9051        APARTMENT           APARTMENT  260000
# 3  20315799      9051        APARTMENT           APARTMENT  325000
# 4  20315776      9051        APARTMENT           APARTMENT  365000
#
#        Type of sale  Number of rooms  Living Area  Fully equipped kitchen  \
# 0  residential_sale                3        160.0                     1.0
# 1  residential_sale                3         96.0                     1.0
# 2  residential_sale                1         76.0                     1.0
# 3  residential_sale                1         81.0                     1.0
# 4  residential_sale                3        101.0                     1.0
#
#    Furnished  ...  Terrace  Terrace area  Garden  Garden area  \
# 0        0.0  ...      1.0          40.0     1.0        290.0
# 1        0.0  ...      1.0          29.0     NaN          NaN
# 2        0.0  ...      1.0          12.0     NaN          NaN
# 3        0.0  ...      1.0          13.0     NaN          NaN
# 4        0.0  ...      1.0          13.0     NaN          NaN
#
#    Surface of the land  Surface area of the plot of land  Number of facades  \
# 0                290.0                               NaN                NaN
# 1                  NaN                               NaN                2.0
# 2                  NaN                               NaN                NaN
# 3                  NaN                               NaN                NaN
# 4                  NaN                               NaN                NaN
#
#    Swimming pool  State of the building Compound Listing
# 0            0.0                   GOOD           single
# 1            0.0                 AS_NEW         compound
# 2            NaN                   GOOD         compound
# 3            NaN                   GOOD         compound
# 4            NaN                   GOOD         compound
#
# [5 rows x 21 columns]

# %%
# Number rows and columns
data.shape
# Out:
# (15516, 21)

# %% [markdown]
# ## Find and handle duplicates

# %%
# Complete duplicates

duplicates_complete = data.duplicated(keep= False) # On all columns, show all the duplicates (keep none, first or last)
data[duplicates_complete].sort_values(by= 'id') # Complete duplicates
# Out:
#              id  Locality Type of property   Subtype of property    Price  \
# 499     9380777      8430        APARTMENT             APARTMENT   311500
# 1402    9380777      8430        APARTMENT             APARTMENT   311500
# 13036   9380780      8430        APARTMENT             APARTMENT   297000
# 12133   9380780      8430        APARTMENT             APARTMENT   297000
# 5282    9380781      8430        APARTMENT             APARTMENT   321500
# ...         ...       ...              ...                   ...      ...
# 13496  20319797      9100            HOUSE                 HOUSE   430000
# 6083   20320128      8310            HOUSE                 VILLA   245000
# 13840  20320128      8310            HOUSE                 VILLA   245000
# 9962   20320926      8200            HOUSE  EXCEPTIONAL_PROPERTY  1935000
# 2204   20320926      8200            HOUSE  EXCEPTIONAL_PROPERTY  1935000
#
#            Type of sale  Number of rooms  Living Area  Fully equipped kitchen  \
# 499    residential_sale                2         79.0                     NaN
# 1402   residential_sale                2         79.0                     NaN
# 13036  residential_sale                2         82.0                     NaN
# 12133  residential_sale                2         82.0                     NaN
# 5282   residential_sale                2         79.0                     NaN
# ...                 ...              ...          ...                     ...
# 13496  residential_sale                5        188.0                     1.0
# 6083   residential_sale                3          NaN                     NaN
# 13840  residential_sale                3          NaN                     NaN
# 9962   residential_sale                6        718.0                     1.0
# 2204   residential_sale                6        718.0                     1.0
#
#        Furnished  ...  Terrace  Terrace area  Garden  Garden area  \
# 499          NaN  ...      1.0          11.0     NaN          NaN
# 1402         NaN  ...      1.0          11.0     NaN          NaN
# 13036        NaN  ...      1.0          11.0     NaN          NaN
# 12133        NaN  ...      1.0          11.0     NaN          NaN
# 5282         NaN  ...      1.0          11.0     NaN          NaN
# ...          ...  ...      ...           ...     ...          ...
# 13496        NaN  ...      1.0           NaN     1.0        120.0
# 6083         0.0  ...      NaN           NaN     NaN          NaN
# 13840        0.0  ...      NaN           NaN     NaN          NaN
# 9962         0.0  ...      1.0           NaN     NaN          NaN
# 2204         0.0  ...      1.0           NaN     NaN          NaN
#
#        Surface of the land  Surface area of the plot of land  \
# 499                    NaN                               NaN
# 1402                   NaN                               NaN
# 13036                  NaN                               NaN
# 12133                  NaN                               NaN
# 5282                   NaN                               NaN
# ...                    ...                               ...
# 13496                120.0                             375.0
# 6083                   NaN                             301.0
# 13840                  NaN                             301.0
# 9962                   NaN                            5085.0
# 2204                   NaN                            5085.0
#
#        Number of facades  Swimming pool  State of the building  \
# 499                  NaN            NaN                   GOOD
# 1402                 NaN            NaN                   GOOD
# 13036                NaN            NaN                   GOOD
# 12133                NaN            NaN                   GOOD
# 5282                 NaN            NaN                   GOOD
# ...                  ...            ...                    ...
# 13496                NaN            NaN                    NaN
# 6083                 NaN            NaN            TO_RENOVATE
# 13840                NaN            NaN            TO_RENOVATE
# 9962                 4.0            1.0                 AS_NEW
# 2204                 4.0            1.0                 AS_NEW
#
#       Compound Listing
# 499           compound
# 1402          compound
# 13036         compound
# 12133         compound
# 5282          compound
# ...                ...
# 13496           single
# 6083            single
# 13840           single
# 9962            single
# 2204            single
#
# [3069 rows x 21 columns]

# %%
# 3096 rows.... drop complete duplicates
# 1551 rows / 15516 = 10% données
data.drop_duplicates(inplace= True)
data.shape
# Out:
# (13965, 21)

# %%
# Based on ImmoWeb code - 0 rows, good!
duplicates_code = data.duplicated(['id'], keep= False) # On id, show all the duplicates (keep none, first or last)
data[duplicates_code].sort_values(by= 'id') # Duplicated immoweb id
# Out:
# Empty DataFrame
# Columns: [id, Locality, Type of property, Subtype of property, Price, Type of sale, Number of rooms, Living Area, Fully equipped kitchen, Furnished, Fireplace, Terrace, Terrace area, Garden, Garden area, Surface of the land, Surface area of the plot of land, Number of facades, Swimming pool, State of the building, Compound Listing]
# Index: []
#
# [0 rows x 21 columns]

# %%
# Check for duplicates on everything except code - 1402 rows.... 
# some clearly duplicates, others are just multiple similar apartments in new project

duplicates_other = data.duplicated(subset= list(data.columns)[1:], keep= False)
data[duplicates_other].sort_values(by= ['Locality', 'Price'])
# Out:
#              id  Locality Type of property Subtype of property   Price  \
# 427     9887765      1000        APARTMENT           APARTMENT  216500
# 3284   20027573      1000        APARTMENT                 KOT  216500
# 4306    9887769      1000        APARTMENT           APARTMENT  216500
# 11041  20027550      1000        APARTMENT                 KOT  216500
# 12063   9887764      1000        APARTMENT           APARTMENT  216500
# ...         ...       ...              ...                 ...     ...
# 14775  20317621      9940        APARTMENT        GROUND_FLOOR  410000
# 9      20317589      9940        APARTMENT           PENTHOUSE  445000
# 5951   20317623      9940        APARTMENT           PENTHOUSE  445000
# 6753   20317652      9940        APARTMENT           PENTHOUSE  445000
# 10811  20317554      9940        APARTMENT           PENTHOUSE  445000
#
#            Type of sale  Number of rooms  Living Area  Fully equipped kitchen  \
# 427    residential_sale                1         24.0                     1.0
# 3284   residential_sale                0         24.0                     1.0
# 4306   residential_sale                1         24.0                     1.0
# 11041  residential_sale                0         24.0                     1.0
# 12063  residential_sale                1         24.0                     1.0
# ...                 ...              ...          ...                     ...
# 14775  residential_sale                3        146.0                     1.0
# 9      residential_sale                2        122.0                     1.0
# 5951   residential_sale                2        122.0                     1.0
# 6753   residential_sale                2        122.0                     1.0
# 10811  residential_sale                2        122.0                     1.0
#
#        Furnished  ...  Terrace  Terrace area  Garden  Garden area  \
# 427          NaN  ...      NaN           NaN     NaN          NaN
# 3284         1.0  ...      NaN           NaN     NaN          NaN
# 4306         NaN  ...      NaN           NaN     NaN          NaN
# 11041        1.0  ...      NaN           NaN     NaN          NaN
# 12063        NaN  ...      NaN           NaN     NaN          NaN
# ...          ...  ...      ...           ...     ...          ...
# 14775        0.0  ...      1.0          29.0     NaN          NaN
# 9            0.0  ...      1.0          48.0     NaN          NaN
# 5951         0.0  ...      1.0          48.0     NaN          NaN
# 6753         0.0  ...      1.0          48.0     NaN          NaN
# 10811        0.0  ...      1.0          48.0     NaN          NaN
#
#        Surface of the land  Surface area of the plot of land  \
# 427                    NaN                               NaN
# 3284                   NaN                               NaN
# 4306                   NaN                               NaN
# 11041                  NaN                               NaN
# 12063                  NaN                               NaN
# ...                    ...                               ...
# 14775                  NaN                               NaN
# 9                      NaN                               NaN
# 5951                   NaN                               NaN
# 6753                   NaN                               NaN
# 10811                  NaN                               NaN
#
#        Number of facades  Swimming pool  State of the building  \
# 427                  NaN            NaN                    NaN
# 3284                 2.0            0.0                 AS_NEW
# 4306                 NaN            NaN                    NaN
# 11041                2.0            0.0                 AS_NEW
# 12063                NaN            NaN                    NaN
# ...                  ...            ...                    ...
# 14775                2.0            0.0                 AS_NEW
# 9                    2.0            0.0                 AS_NEW
# 5951                 2.0            0.0                 AS_NEW
# 6753                 2.0            0.0                 AS_NEW
# 10811                2.0            0.0                 AS_NEW
#
#       Compound Listing
# 427           compound
# 3284          compound
# 4306          compound
# 11041         compound
# 12063         compound
# ...                ...
# 14775           single
# 9             compound
# 5951            single
# 6753          compound
# 10811           single
#
# [1402 rows x 21 columns]

# %%
# Since are duplicated in ALL values, except for ID - assume are duplicated listings
# To check, this loses 843 rows - representing 6.04% of data

column_names = list(data.columns)[1:]
data.drop_duplicates(subset = column_names, inplace= True)
data.shape
# Out:
# (13122, 21)

# %%
# Check for duplicates on postal code, price etc
# Based on compound properties with multiple similar listings, multiple listings for different agenciies...
# Check how much data lose if just completely remove all these duplicates, keeping, in theory, only one property per compound property
# And per multiple listing for same property
# Data cleaner, no influence on means, medians etc.... better for analysis
# Does not represent huge amount of data to lose
# Go through case by case too labour-intensive for practical purposes

duplicates_postpricearea = data.duplicated(['Locality', 'Price', 'Living Area', 'Number of rooms'], keep= False)
data[duplicates_postpricearea].sort_values(by= ['Locality', 'Price'])
# Out:
# Empty DataFrame
# Columns: [id, Locality, Type of property, Subtype of property, Price, Type of sale, Number of rooms, Living Area, Fully equipped kitchen, Furnished, Fireplace, Terrace, Terrace area, Garden, Garden area, Surface of the land, Surface area of the plot of land, Number of facades, Swimming pool, State of the building, Compound Listing]
# Index: []
#
# [0 rows x 21 columns]

# %%
# dropped 1197 / 13122 lines = 9.12% data loss
# Large amount of observations - but final dataset still above 10.000 observations AND cleaner than if left duplicates
# Value clean data, and remove influence of duplication on analysis rather than amount of data
# Pretty sure now that all rows in dataset are individual properties - even if lost properties very similar in new projects

column_names = ['Locality', 'Price', 'Living Area', 'Number of rooms']
data.drop_duplicates(subset = column_names, inplace= True)
data.shape
# Out:
# (11925, 21)

# %% [markdown]
# ## Missing data

# %%
# Finding rows with number of NaN
data[data.isna().sum(axis=1) == 9]

# 16 rows 12 NaN
# 246 rows 11
# 345 10
# 1152 9
# Out:
#              id  Locality Type of property Subtype of property   Price  \
# 17     20313211      1070        APARTMENT                 KOT  132350
# 18     20313093      1070        APARTMENT                 KOT  132350
# 19     20313081      1070        APARTMENT                 KOT  132350
# 20     20313169      1070        APARTMENT                 KOT  132350
# 21     20313171      1070        APARTMENT                 KOT  132350
# ...         ...       ...              ...                 ...     ...
# 15402  20134491      8660        APARTMENT           PENTHOUSE  795000
# 15415  20308471      8800            HOUSE               HOUSE  639000
# 15470  20270287      3000        APARTMENT           APARTMENT  215000
# 15488  20162961      3530            HOUSE               HOUSE  299000
# 15506  20109298      8300        APARTMENT           APARTMENT  595000
#
#            Type of sale  Number of rooms  Living Area  Fully equipped kitchen  \
# 17     residential_sale                0         17.0                     NaN
# 18     residential_sale                0         17.0                     NaN
# 19     residential_sale                0         17.0                     NaN
# 20     residential_sale                0         17.0                     NaN
# 21     residential_sale                0         17.0                     NaN
# ...                 ...              ...          ...                     ...
# 15402  residential_sale                3        155.0                     NaN
# 15415  residential_sale                3        224.0                     NaN
# 15470  residential_sale                1         22.0                     NaN
# 15488  residential_sale                3        190.0                     NaN
# 15506  residential_sale                2         62.0                     NaN
#
#        Furnished  ...  Terrace  Terrace area  Garden  Garden area  \
# 17           NaN  ...      NaN           NaN     NaN          NaN
# 18           NaN  ...      NaN           NaN     NaN          NaN
# 19           NaN  ...      NaN           NaN     NaN          NaN
# 20           NaN  ...      NaN           NaN     NaN          NaN
# 21           NaN  ...      NaN           NaN     NaN          NaN
# ...          ...  ...      ...           ...     ...          ...
# 15402        NaN  ...      1.0           NaN     NaN          NaN
# 15415        NaN  ...      NaN           NaN     NaN          NaN
# 15470        NaN  ...      1.0           NaN     NaN          NaN
# 15488        NaN  ...      NaN           NaN     NaN          NaN
# 15506        NaN  ...      NaN           NaN     NaN          NaN
#
#        Surface of the land  Surface area of the plot of land  \
# 17                     NaN                               NaN
# 18                     NaN                               NaN
# 19                     NaN                               NaN
# 20                     NaN                               NaN
# 21                     NaN                               NaN
# ...                    ...                               ...
# 15402                  NaN                               NaN
# 15415                  NaN                             420.0
# 15470                  NaN                               NaN
# 15488                  NaN                            2108.0
# 15506                  NaN                               NaN
#
#        Number of facades  Swimming pool  State of the building  \
# 17                   2.0            NaN                 AS_NEW
# 18                   2.0            NaN                 AS_NEW
# 19                   2.0            NaN                 AS_NEW
# 20                   2.0            NaN                 AS_NEW
# 21                   2.0            NaN                 AS_NEW
# ...                  ...            ...                    ...
# 15402                NaN            NaN                   GOOD
# 15415                3.0            NaN                    NaN
# 15470                NaN            NaN                   GOOD
# 15488                NaN            NaN            TO_RENOVATE
# 15506                2.0            NaN                 AS_NEW
#
#       Compound Listing
# 17            compound
# 18            compound
# 19            compound
# 20            compound
# 21            compound
# ...                ...
# 15402           single
# 15415           single
# 15470           single
# 15488           single
# 15506           single
#
# [1152 rows x 21 columns]

# %% [markdown]
# ## Data type constraints

# %%
# Check data types and null values
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11925 entries, 0 to 15515
# Data columns (total 21 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                11925 non-null  int64
#  1   Locality                          11925 non-null  object
#  2   Type of property                  11925 non-null  object
#  3   Subtype of property               11925 non-null  object
#  4   Price                             11925 non-null  float64
#  5   Type of sale                      11925 non-null  object
#  6   Number of rooms                   11925 non-null  int64
#  7   Living Area                       11736 non-null  float64
#  8   Fully equipped kitchen            8292 non-null   float64
#  9   Furnished                         5540 non-null   float64
#  10  Fireplace                         11925 non-null  int64
#  11  Terrace                           9202 non-null   float64
#  12  Terrace area                      6857 non-null   float64
#  13  Garden                            2545 non-null   float64
#  14  Garden area                       2545 non-null   float64
#  15  Surface of the land               2545 non-null   float64
#  16  Surface area of the plot of land  4207 non-null   float64
#  17  Number of facades                 7615 non-null   float64
#  18  Swimming pool                     4270 non-null   float64
#  19  State of the building             9179 non-null   object
#  20  Compound Listing                  11925 non-null  object
# dtypes: float64(12), int64(3), object(6)
# memory usage: 2.0+ MB

# %%
# Fix data types
# Boolean 0/1 values pres-abs can be left in float to preserve NaN ; int doesn't take NaN and not necessary to convert to string
# OPM : for EDA, but in modelling, does leaving float assume continuous variable and error, instead of one-hot encoding
# Fireplace int (because no missing data)

data['Locality'] = data['Locality'].astype('str')
data['Price'] = data['Price'].astype('float')
#data['Fully equipped kitchen'] = data['Fully equipped kitchen'].fillna(-1).astype('int64')
#data['Fully equipped kitchen'] = data['Fully equipped kitchen'].replace(-1, np.nan)
#data['Furnished'] = data['Furnished'].fillna(-1).astype('str')
#data['Furnished'] = data['Furnished'].replace(-1, np.nan)
#data['Terrace'] = data['Terrace'].fillna(-1).astype('int64')
#data['Terrace'] = data['Terrace'].replace(-1, np.nan)
#data['Garden'] = data['Garden'].fillna(-1).astype('int64')
#data['Garden'] = data['Garden'].replace(-1, np.nan)
#data['Number of facades'] = data['Number of facades'].fillna(-1).astype('int64')
#data['Number of facades'] = data['Number of facades'].replace(-1, np.nan)
#data['Swimming pool'] = data['Swimming pool'].fillna(-1).astype('int64')
#data['Swimming pool'] = data['Swimming pool'].replace(-1, np.nan)

# %% [markdown]
# ## Verifying categorical values - value consistency
# ### Postal code

# %%
data[data['Locality'].apply(lambda x: len(x) != 4)] # All postalcodes are 4 digits long
# Out:
# Empty DataFrame
# Columns: [id, Locality, Type of property, Subtype of property, Price, Type of sale, Number of rooms, Living Area, Fully equipped kitchen, Furnished, Fireplace, Terrace, Terrace area, Garden, Garden area, Surface of the land, Surface area of the plot of land, Number of facades, Swimming pool, State of the building, Compound Listing]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ### Type of property
# All properties either APARTMENT or HOUSE

# %%
data['Type of property'].value_counts()
# Out:
# Type of property
# APARTMENT    7718
# HOUSE        4207
# Name: count, dtype: int64

# %% [markdown]
# ### Subtype of property
# Many different categories and strong group imbalance
# BUT subtype - so exclude from analysis
# - reassign those can reassign
# - drop really low categories

# %%
data['Subtype of property'].value_counts()
# Out:
# Subtype of property
# APARTMENT               6355
# HOUSE                   3154
# VILLA                    397
# GROUND_FLOOR             381
# PENTHOUSE                330
# FLAT_STUDIO              270
# DUPLEX                   235
# MIXED_USE_BUILDING       168
# APARTMENT_BLOCK          152
# EXCEPTIONAL_PROPERTY      76
# MANSION                   76
# TOWN_HOUSE                53
# COUNTRY_COTTAGE           53
# BUNGALOW                  47
# KOT                       45
# SERVICE_FLAT              44
# LOFT                      40
# FARMHOUSE                 18
# TRIPLEX                   18
# CHALET                     5
# MANOR_HOUSE                4
# CASTLE                     3
# OTHER_PROPERTY             1
# Name: count, dtype: int64

# %% [markdown]
# ### Type of sale
# All are of same type - residential_sale
# -> Drop column

# %%
data['Type of sale'].value_counts()
# Out:
# Type of sale
# residential_sale    11925
# Name: count, dtype: int64

# %% [markdown]
# ### Fully equipped kitchen
# Two values, ok

# %%
data['Fully equipped kitchen'].value_counts()
# Out:
# Fully equipped kitchen
# 1.0    8292
# Name: count, dtype: int64

# %% [markdown]
# ### Compound listing
# All of correct values, single or compound

# %%
data['Compound Listing'].value_counts()
# Out:
# Compound Listing
# single      7388
# compound    4537
# Name: count, dtype: int64

# %% [markdown]
# ### State of the building
#
# Strong group imbalance
# - GOOD/AS_NEW
# - TO_RENOVATE/TO_BE_DONE_UP/JUST_RENOVATED/TO_RESTORE
#
# Reassign NaN?
# Reassign values? TO_RENOVATE/TO_BE_DONE_UP/TO_RESTORE and AS_NEW/JUST_RENOVATED

# %%
data['State of the building'].value_counts()
# Out:
# State of the building
# GOOD              4123
# AS_NEW            2887
# TO_RENOVATE        844
# TO_BE_DONE_UP      721
# JUST_RENOVATED     576
# TO_RESTORE          28
# Name: count, dtype: int64

# %% [markdown]
# ### Furnished
# 2 values or Nan - ok

# %%
data['Furnished'].value_counts()
# Out:
# Furnished
# 0.0    5165
# 1.0     375
# Name: count, dtype: int64

# %% [markdown]
# ### Fireplace
# Two values - ok

# %%
data['Fireplace'].value_counts()
# Out:
# Fireplace
# 0    11545
# 1      380
# Name: count, dtype: int64

# %% [markdown]
# ### Terrace
# All 1 or NaN - ok

# %%
data['Terrace'].value_counts()
# Out:
# Terrace
# 1.0    9202
# Name: count, dtype: int64

# %% [markdown]
# ### Garden
# all 1 or NaN - ok

# %%
data['Garden'].value_counts()
# Out:
# Garden
# 1.0    2545
# Name: count, dtype: int64

# %% [markdown]
# ### Swimming pool
# Two values or NaN - ok

# %%
data['Swimming pool'].value_counts()
# Out:
# Swimming pool
# 0.0    4037
# 1.0     233
# Name: count, dtype: int64

# %% [markdown]
# ## Verifying numerical data

# %%
data[['Price', 'Number of rooms', 'Living Area', 'Terrace area', 'Garden area', 'Surface of the land', 'Surface area of the plot of land', 'Number of facades']].describe()
# Out:
#               Price  Number of rooms   Living Area  Terrace area  \
# count  1.192500e+04     11925.000000  11736.000000   6857.000000
# mean   4.430277e+05         2.560252    142.647580     22.340090
# std    3.858024e+05         1.358437    120.841899     53.861694
# min    2.750000e+04         0.000000      5.000000      1.000000
# 25%    2.600000e+05         2.000000     87.000000      9.000000
# 50%    3.480000e+05         2.000000    110.000000     14.000000
# 75%    4.850000e+05         3.000000    164.000000     25.000000
# max    6.495000e+06        25.000000   4829.000000   3749.000000
#
#         Garden area  Surface of the land  Surface area of the plot of land  \
# count   2545.000000          2545.000000                       4207.000000
# mean     525.212967           525.212967                       1088.504873
# std     1312.464646          1312.464646                       3199.257047
# min        1.000000             1.000000                          0.000000
# 25%       56.000000            56.000000                        180.000000
# 50%      150.000000           150.000000                        400.000000
# 75%      477.000000           477.000000                        893.500000
# max    18131.000000         18131.000000                      64300.000000
#
#        Number of facades
# count        7615.000000
# mean            2.732108
# std             0.855881
# min             1.000000
# 25%             2.000000
# 50%             2.000000
# 75%             4.000000
# max             6.000000

# %%
plt.hist(data['Surface area of the plot of land'])
plt.title('Surface plot of land')
plt.show()
# Severely skewed distribution ; remove > 10000 (68 rows)?

# %%
data[data['Surface area of the plot of land'] >= 10000]
# Out:
#              id Locality Type of property   Subtype of property      Price  \
# 329    20287191     9700            HOUSE       COUNTRY_COTTAGE   345000.0
# 706    20290335     3450            HOUSE                 HOUSE   553000.0
# 720    20285258     8610            HOUSE             FARMHOUSE   649000.0
# 831    20286621     8740            HOUSE                 VILLA  1895000.0
# 973    20262952     8750            HOUSE       COUNTRY_COTTAGE  1775000.0
# ...         ...      ...              ...                   ...        ...
# 14500  20320348     5590            HOUSE    MIXED_USE_BUILDING  1200000.0
# 14612  20311372     8520            HOUSE       COUNTRY_COTTAGE   735000.0
# 15285  20274134     3800            HOUSE       COUNTRY_COTTAGE  1298000.0
# 15297  20304356     1473            HOUSE  EXCEPTIONAL_PROPERTY   950000.0
# 15432  20303201     4870            HOUSE       APARTMENT_BLOCK  1245000.0
#
#            Type of sale  Number of rooms  Living Area  Fully equipped kitchen  \
# 329    residential_sale                3        302.0                     1.0
# 706    residential_sale                4        209.0                     1.0
# 720    residential_sale                5        314.0                     1.0
# 831    residential_sale                8        334.0                     NaN
# 973    residential_sale                7        696.0                     NaN
# ...                 ...              ...          ...                     ...
# 14500  residential_sale                9        556.0                     1.0
# 14612  residential_sale                4        250.0                     1.0
# 15285  residential_sale                5        453.0                     NaN
# 15297  residential_sale                7        382.0                     NaN
# 15432  residential_sale               12        814.0                     1.0
#
#        Furnished  ...  Terrace  Terrace area  Garden  Garden area  \
# 329          0.0  ...      1.0           NaN     NaN          NaN
# 706          0.0  ...      1.0           NaN     NaN          NaN
# 720          0.0  ...      NaN           NaN     NaN          NaN
# 831          NaN  ...      1.0           NaN     NaN          NaN
# 973          NaN  ...      1.0           NaN     NaN          NaN
# ...          ...  ...      ...           ...     ...          ...
# 14500        NaN  ...      1.0           NaN     1.0      13406.0
# 14612        NaN  ...      1.0           NaN     NaN          NaN
# 15285        NaN  ...      NaN           NaN     NaN          NaN
# 15297        NaN  ...      NaN           NaN     NaN          NaN
# 15432        0.0  ...      1.0           NaN     NaN          NaN
#
#        Surface of the land  Surface area of the plot of land  \
# 329                    NaN                           34690.0
# 706                    NaN                           23503.0
# 720                    NaN                           23912.0
# 831                    NaN                           18262.0
# 973                    NaN                           19664.0
# ...                    ...                               ...
# 14500              13406.0                           13406.0
# 14612                  NaN                           12518.0
# 15285                  NaN                           19223.0
# 15297                  NaN                           15400.0
# 15432                  NaN                           28600.0
#
#        Number of facades  Swimming pool  State of the building  \
# 329                  4.0            0.0            TO_RENOVATE
# 706                  3.0            0.0                   GOOD
# 720                  NaN            NaN            TO_RENOVATE
# 831                  4.0            NaN                   GOOD
# 973                  4.0            NaN                 AS_NEW
# ...                  ...            ...                    ...
# 14500                4.0            NaN                    NaN
# 14612                4.0            NaN            TO_RENOVATE
# 15285                3.0            1.0                 AS_NEW
# 15297                4.0            1.0          TO_BE_DONE_UP
# 15432                4.0            0.0                   GOOD
#
#       Compound Listing
# 329             single
# 706             single
# 720             single
# 831             single
# 973             single
# ...                ...
# 14500           single
# 14612           single
# 15285           single
# 15297           single
# 15432           single
#
# [65 rows x 21 columns]

# %%
plt.hist(data['Surface area of the plot of land'])
plt.title('Surface area of the plot of land')
plt.show()

# Drop >= 10_000 (68 rows)

# %%
data[data['Surface area of the plot of land'] >= 10_000]
# Out:
#              id Locality Type of property   Subtype of property      Price  \
# 329    20287191     9700            HOUSE       COUNTRY_COTTAGE   345000.0
# 706    20290335     3450            HOUSE                 HOUSE   553000.0
# 720    20285258     8610            HOUSE             FARMHOUSE   649000.0
# 831    20286621     8740            HOUSE                 VILLA  1895000.0
# 973    20262952     8750            HOUSE       COUNTRY_COTTAGE  1775000.0
# ...         ...      ...              ...                   ...        ...
# 14612  20311372     8520            HOUSE       COUNTRY_COTTAGE   735000.0
# 15285  20274134     3800            HOUSE       COUNTRY_COTTAGE  1298000.0
# 15297  20304356     1473            HOUSE  EXCEPTIONAL_PROPERTY   950000.0
# 15432  20303201     4870            HOUSE       APARTMENT_BLOCK  1245000.0
# 15459  11446091     9185            HOUSE    MIXED_USE_BUILDING  1299000.0
#
#            Type of sale  Number of rooms  Living Area  Fully equipped kitchen  \
# 329    residential_sale                3        302.0                       1
# 706    residential_sale                4        209.0                       1
# 720    residential_sale                5        314.0                       1
# 831    residential_sale                8        334.0                      -1
# 973    residential_sale                7        696.0                      -1
# ...                 ...              ...          ...                     ...
# 14612  residential_sale                4        250.0                       1
# 15285  residential_sale                5        453.0                      -1
# 15297  residential_sale                7        382.0                      -1
# 15432  residential_sale               12        814.0                       1
# 15459  residential_sale                3        220.0                       1
#
#       Furnished  ...  Terrace  Terrace area  Garden  Garden area  \
# 329         0.0  ...        1           NaN      -1          NaN
# 706         0.0  ...        1           NaN      -1          NaN
# 720         0.0  ...       -1           NaN      -1          NaN
# 831        -1.0  ...        1           NaN      -1          NaN
# 973        -1.0  ...        1           NaN      -1          NaN
# ...         ...  ...      ...           ...     ...          ...
# 14612      -1.0  ...        1           NaN      -1          NaN
# 15285      -1.0  ...       -1           NaN      -1          NaN
# 15297      -1.0  ...       -1           NaN      -1          NaN
# 15432       0.0  ...        1           NaN      -1          NaN
# 15459      -1.0  ...        1           NaN      -1          NaN
#
#        Surface of the land  Surface area of the plot of land  \
# 329                    NaN                           34690.0
# 706                    NaN                           23503.0
# 720                    NaN                           23912.0
# 831                    NaN                           18262.0
# 973                    NaN                           19664.0
# ...                    ...                               ...
# 14612                  NaN                           12518.0
# 15285                  NaN                           19223.0
# 15297                  NaN                           15400.0
# 15432                  NaN                           28600.0
# 15459                  NaN                           14569.0
#
#        Number of facades  Swimming pool  State of the building  \
# 329                    4              0            TO_RENOVATE
# 706                    3              0                   GOOD
# 720                   -1             -1            TO_RENOVATE
# 831                    4             -1                   GOOD
# 973                    4             -1                 AS_NEW
# ...                  ...            ...                    ...
# 14612                  4             -1            TO_RENOVATE
# 15285                  3              1                 AS_NEW
# 15297                  4              1          TO_BE_DONE_UP
# 15432                  4              0                   GOOD
# 15459                 -1             -1                   GOOD
#
#       Compound Listing
# 329             single
# 706             single
# 720             single
# 831             single
# 973             single
# ...                ...
# 14612           single
# 15285           single
# 15297           single
# 15432           single
# 15459           single
#
# [68 rows x 21 columns]

# %%
plt.hist(data['Surface of the land'])
plt.title('Surface of land')
plt.show()

# Severely skewed dist - remove >= 2500 (93 rows)?

# %%
data[data['Surface of the land'] >= 2500] # outlier but sound
# Out:
#              id Locality Type of property Subtype of property      Price  \
# 93     20318858     1350            HOUSE               HOUSE   769000.0
# 728    10938778     1180            HOUSE               VILLA  1800000.0
# 766    20148041     4000            HOUSE               VILLA   595000.0
# 811    20237920     4900            HOUSE               HOUSE   595000.0
# 882    20210234     2930            HOUSE               HOUSE  1980000.0
# ...         ...      ...              ...                 ...        ...
# 14720  20253603     3220            HOUSE               HOUSE   370000.0
# 14986  20063113     5380        APARTMENT           APARTMENT   399000.0
# 15138  20311635     1400        APARTMENT           APARTMENT   159000.0
# 15335  11211770     3090            HOUSE               VILLA  1195000.0
# 15378  20005946     1390            HOUSE               HOUSE  1150000.0
#
#            Type of sale  Number of rooms  Living Area  Fully equipped kitchen  \
# 93     residential_sale                5        222.0                       1
# 728    residential_sale                4        219.0                       1
# 766    residential_sale                7        455.0                       1
# 811    residential_sale                4        214.0                       1
# 882    residential_sale                5        689.0                       1
# ...                 ...              ...          ...                     ...
# 14720  residential_sale                5        195.0                       1
# 14986  residential_sale                3        115.0                      -1
# 15138  residential_sale                2         75.0                       1
# 15335  residential_sale                5        349.0                       1
# 15378  residential_sale                5        400.0                       1
#
#       Furnished  ...  Terrace  Terrace area  Garden  Garden area  \
# 93          0.0  ...        1          20.0       1       9310.0
# 728         0.0  ...        1         150.0       1       5000.0
# 766        -1.0  ...        1          28.0       1       3100.0
# 811         0.0  ...        1          18.0       1       2908.0
# 882        -1.0  ...       -1           NaN       1       3149.0
# ...         ...  ...      ...           ...     ...          ...
# 14720      -1.0  ...        1          20.0       1       2500.0
# 14986      -1.0  ...        1          55.0       1       6803.0
# 15138       0.0  ...        1          13.0       1      10000.0
# 15335       0.0  ...        1         130.0       1       5000.0
# 15378       0.0  ...        1           NaN       1       3000.0
#
#        Surface of the land  Surface area of the plot of land  \
# 93                  9310.0                            9592.0
# 728                 5000.0                            5500.0
# 766                 3100.0                            3333.0
# 811                 2908.0                            3094.0
# 882                 3149.0                            3149.0
# ...                    ...                               ...
# 14720               2500.0                            3133.0
# 14986               6803.0                               NaN
# 15138              10000.0                               NaN
# 15335               5000.0                            6162.0
# 15378               3000.0                            4999.0
#
#        Number of facades  Swimming pool  State of the building  \
# 93                     4              0                 AS_NEW
# 728                    4              0            TO_RENOVATE
# 766                    4             -1            TO_RENOVATE
# 811                    4              1                   GOOD
# 882                   -1              1                   GOOD
# ...                  ...            ...                    ...
# 14720                  4             -1            TO_RENOVATE
# 14986                 -1             -1                   GOOD
# 15138                  4              0                   GOOD
# 15335                  4              0                   GOOD
# 15378                  4              0                   GOOD
#
#       Compound Listing
# 93              single
# 728             single
# 766             single
# 811             single
# 882             single
# ...                ...
# 14720           single
# 14986         compound
# 15138           single
# 15335           single
# 15378           single
#
# [93 rows x 21 columns]

# %%
plt.hist(data['Terrace area'])
plt.title('Terrace area')
plt.show()

# Drop >= 250 ? (19 rows)

# %%
data[data['Terrace area'] >= 250]
# Out:
#              id Locality Type of property   Subtype of property      Price  \
# 2090   20301177     4140            HOUSE                 HOUSE   899000.0
# 3349   20063106     5380        APARTMENT             APARTMENT   384000.0
# 4103   20151817     1050        APARTMENT             PENTHOUSE  4000000.0
# 4180   20142914     8300            HOUSE                 VILLA  1395000.0
# 5095   20301183     4140            HOUSE       APARTMENT_BLOCK   899000.0
# 5904   20312136     4340            HOUSE    MIXED_USE_BUILDING   950000.0
# 6870   20308014     4350            HOUSE  EXCEPTIONAL_PROPERTY   850000.0
# 7228   20063116     5380        APARTMENT             APARTMENT   389000.0
# 7991   20302351     4960        APARTMENT          GROUND_FLOOR   280000.0
# 8594   20057079     4820            HOUSE                 HOUSE   350000.0
# 11106  20063104     5380        APARTMENT             APARTMENT   325000.0
# 11176  20155994     5170        APARTMENT             APARTMENT   420000.0
# 11915  20288092     6890            HOUSE  EXCEPTIONAL_PROPERTY   449000.0
# 13647  20308015     4300            HOUSE  EXCEPTIONAL_PROPERTY   850000.0
# 14630  20311467     2830            HOUSE                 HOUSE   369000.0
# 14671  20161665     1000        APARTMENT             PENTHOUSE  4000000.0
# 14984  20063115     5380        APARTMENT             APARTMENT   315000.0
# 15055  20155975     5170        APARTMENT             APARTMENT   420000.0
# 15178  20276050     9700        APARTMENT             PENTHOUSE  1850000.0
#
#            Type of sale  Number of rooms  Living Area  Fully equipped kitchen  \
# 2090   residential_sale               13        778.0                       1
# 3349   residential_sale                3        119.0                      -1
# 4103   residential_sale                4        444.0                       1
# 4180   residential_sale                4        276.0                       1
# 5095   residential_sale               13        778.0                       1
# 5904   residential_sale                2        375.0                       1
# 6870   residential_sale                5        365.0                       1
# 7228   residential_sale                3        122.0                      -1
# 7991   residential_sale                3        129.0                       1
# 8594   residential_sale                3        180.0                       1
# 11106  residential_sale                2         88.0                      -1
# 11176  residential_sale                3        146.0                       1
# 11915  residential_sale                5        400.0                       1
# 13647  residential_sale                5        365.0                       1
# 14630  residential_sale                4        188.0                       1
# 14671  residential_sale                4        444.0                       1
# 14984  residential_sale                1         75.0                      -1
# 15055  residential_sale                3        146.0                       1
# 15178  residential_sale                3        300.0                       1
#
#       Furnished  ...  Terrace  Terrace area  Garden  Garden area  \
# 2090        0.0  ...        1         443.0      -1          NaN
# 3349       -1.0  ...        1         255.0      -1          NaN
# 4103        0.0  ...        1         253.0      -1          NaN
# 4180        0.0  ...        1         323.0       1        323.0
# 5095        0.0  ...        1         443.0      -1          NaN
# 5904        0.0  ...        1         540.0      -1          NaN
# 6870        0.0  ...        1         250.0       1       3000.0
# 7228       -1.0  ...        1         408.0      -1          NaN
# 7991        0.0  ...        1        3749.0       1         60.0
# 8594        0.0  ...        1         835.0       1        700.0
# 11106      -1.0  ...        1         365.0      -1          NaN
# 11176       0.0  ...        1         972.0      -1          NaN
# 11915       0.0  ...        1         581.0       1        540.0
# 13647       0.0  ...        1         250.0       1       3000.0
# 14630      -1.0  ...        1         430.0      -1          NaN
# 14671       0.0  ...        1         253.0      -1          NaN
# 14984      -1.0  ...        1         364.0      -1          NaN
# 15055       0.0  ...        1         972.0      -1          NaN
# 15178      -1.0  ...        1         300.0      -1          NaN
#
#        Surface of the land  Surface area of the plot of land  \
# 2090                   NaN                            1135.0
# 3349                   NaN                               NaN
# 4103                   NaN                               NaN
# 4180                 323.0                             606.0
# 5095                   NaN                            1135.0
# 5904                   NaN                            2345.0
# 6870                3000.0                            4788.0
# 7228                   NaN                               NaN
# 7991                  60.0                               NaN
# 8594                 700.0                             802.0
# 11106                  NaN                               NaN
# 11176                  NaN                               NaN
# 11915                540.0                            1387.0
# 13647               3000.0                            4788.0
# 14630                  NaN                             582.0
# 14671                  NaN                               NaN
# 14984                  NaN                               NaN
# 15055                  NaN                               NaN
# 15178                  NaN                               NaN
#
#        Number of facades  Swimming pool  State of the building  \
# 2090                   4              0                   GOOD
# 3349                  -1             -1                   GOOD
# 4103                   2             -1                 AS_NEW
# 4180                   4             -1                   GOOD
# 5095                   4              0                   GOOD
# 5904                   4              0                 AS_NEW
# 6870                   4              1                   GOOD
# 7228                  -1             -1                   GOOD
# 7991                   3              0                 AS_NEW
# 8594                   4              0                   GOOD
# 11106                 -1             -1                   GOOD
# 11176                  3              0                 AS_NEW
# 11915                  4              0                 AS_NEW
# 13647                  4              1                   GOOD
# 14630                  3             -1                   GOOD
# 14671                  2             -1                 AS_NEW
# 14984                 -1             -1                   GOOD
# 15055                  3              0                    NaN
# 15178                  2             -1                 AS_NEW
#
#       Compound Listing
# 2090            single
# 3349          compound
# 4103          compound
# 4180            single
# 5095            single
# 5904            single
# 6870            single
# 7228          compound
# 7991            single
# 8594            single
# 11106         compound
# 11176         compound
# 11915           single
# 13647           single
# 14630           single
# 14671         compound
# 14984         compound
# 15055         compound
# 15178           single
#
# [19 rows x 21 columns]

# %%
plt.hist(data['Garden area'])
plt.title('Garden area')
plt.show()

# Drop >= 2500 (93 rows)

# %%
data[data['Garden area'] >= 2500]
# Out:
#              id Locality Type of property Subtype of property      Price  \
# 93     20318858     1350            HOUSE               HOUSE   769000.0
# 728    10938778     1180            HOUSE               VILLA  1800000.0
# 766    20148041     4000            HOUSE               VILLA   595000.0
# 811    20237920     4900            HOUSE               HOUSE   595000.0
# 882    20210234     2930            HOUSE               HOUSE  1980000.0
# ...         ...      ...              ...                 ...        ...
# 14720  20253603     3220            HOUSE               HOUSE   370000.0
# 14986  20063113     5380        APARTMENT           APARTMENT   399000.0
# 15138  20311635     1400        APARTMENT           APARTMENT   159000.0
# 15335  11211770     3090            HOUSE               VILLA  1195000.0
# 15378  20005946     1390            HOUSE               HOUSE  1150000.0
#
#            Type of sale  Number of rooms  Living Area  Fully equipped kitchen  \
# 93     residential_sale                5        222.0                       1
# 728    residential_sale                4        219.0                       1
# 766    residential_sale                7        455.0                       1
# 811    residential_sale                4        214.0                       1
# 882    residential_sale                5        689.0                       1
# ...                 ...              ...          ...                     ...
# 14720  residential_sale                5        195.0                       1
# 14986  residential_sale                3        115.0                      -1
# 15138  residential_sale                2         75.0                       1
# 15335  residential_sale                5        349.0                       1
# 15378  residential_sale                5        400.0                       1
#
#       Furnished  ...  Terrace  Terrace area  Garden  Garden area  \
# 93          0.0  ...        1          20.0       1       9310.0
# 728         0.0  ...        1         150.0       1       5000.0
# 766        -1.0  ...        1          28.0       1       3100.0
# 811         0.0  ...        1          18.0       1       2908.0
# 882        -1.0  ...       -1           NaN       1       3149.0
# ...         ...  ...      ...           ...     ...          ...
# 14720      -1.0  ...        1          20.0       1       2500.0
# 14986      -1.0  ...        1          55.0       1       6803.0
# 15138       0.0  ...        1          13.0       1      10000.0
# 15335       0.0  ...        1         130.0       1       5000.0
# 15378       0.0  ...        1           NaN       1       3000.0
#
#        Surface of the land  Surface area of the plot of land  \
# 93                  9310.0                            9592.0
# 728                 5000.0                            5500.0
# 766                 3100.0                            3333.0
# 811                 2908.0                            3094.0
# 882                 3149.0                            3149.0
# ...                    ...                               ...
# 14720               2500.0                            3133.0
# 14986               6803.0                               NaN
# 15138              10000.0                               NaN
# 15335               5000.0                            6162.0
# 15378               3000.0                            4999.0
#
#        Number of facades  Swimming pool  State of the building  \
# 93                     4              0                 AS_NEW
# 728                    4              0            TO_RENOVATE
# 766                    4             -1            TO_RENOVATE
# 811                    4              1                   GOOD
# 882                   -1              1                   GOOD
# ...                  ...            ...                    ...
# 14720                  4             -1            TO_RENOVATE
# 14986                 -1             -1                   GOOD
# 15138                  4              0                   GOOD
# 15335                  4              0                   GOOD
# 15378                  4              0                   GOOD
#
#       Compound Listing
# 93              single
# 728             single
# 766             single
# 811             single
# 882             single
# ...                ...
# 14720           single
# 14986         compound
# 15138           single
# 15335           single
# 15378           single
#
# [93 rows x 21 columns]

# %%
plt.hist(data['Number of facades'])
plt.title('Number of facades')
plt.show()

# Remove only one (29 rows), and >4 (2 rows) ?

# %%
data[data['Number of facades'] > 4] # error? code to 4
# Out:
#              id Locality Type of property Subtype of property      Price  \
# 1655   20157198     1640            HOUSE               VILLA  1250000.0
# 11517  20147859     1800        APARTMENT           APARTMENT   397296.0
#
#            Type of sale  Number of rooms  Living Area  Fully equipped kitchen  \
# 1655   residential_sale                6        500.0                       1
# 11517  residential_sale                2        119.0                       1
#
#       Furnished  ...  Terrace  Terrace area  Garden  Garden area  \
# 1655       -1.0  ...        1          70.0       1        570.0
# 11517      -1.0  ...        1          12.0      -1          NaN
#
#        Surface of the land  Surface area of the plot of land  \
# 1655                 570.0                            1768.0
# 11517                  NaN                               NaN
#
#        Number of facades  Swimming pool  State of the building  \
# 1655                   6              0                 AS_NEW
# 11517                  5              0                 AS_NEW
#
#       Compound Listing
# 1655            single
# 11517           single
#
# [2 rows x 21 columns]

# %%
data[data['Number of facades'] == 1]
# Out:
#              id Locality Type of property Subtype of property     Price  \
# 647    20312956     4031        APARTMENT           APARTMENT  259000.0
# 776    20319782     2000            HOUSE     APARTMENT_BLOCK  419000.0
# 1180   20240468     1180        APARTMENT           APARTMENT  419000.0
# 1665   20180576     1000        APARTMENT         FLAT_STUDIO  240000.0
# 2163   20308132     8820            HOUSE            BUNGALOW  239000.0
# 2530   20215667     1000        APARTMENT           APARTMENT  285000.0
# 2615   20292204     8420        APARTMENT           APARTMENT  380000.0
# 2627   11273032     8300        APARTMENT           APARTMENT  329900.0
# 2708   20244147     2000        APARTMENT           APARTMENT  419000.0
# 5041   20293509     8380        APARTMENT           APARTMENT  240000.0
# 5059   20240470     1180        APARTMENT           APARTMENT  459000.0
# 5476   20272748     9000        APARTMENT           APARTMENT  175000.0
# 5545   20264487     2018        APARTMENT         FLAT_STUDIO  149000.0
# 6526   20270173     8380        APARTMENT         FLAT_STUDIO  158000.0
# 7454   20321125     9120        APARTMENT           APARTMENT  229000.0
# 7488   20088244     3000        APARTMENT         FLAT_STUDIO  209999.0
# 8683   20316898     8730            HOUSE               HOUSE  385000.0
# 8763   11331213     1190        APARTMENT           APARTMENT  234000.0
# 8937   20240472     1180        APARTMENT         FLAT_STUDIO  285000.0
# 8938   20240471     1180        APARTMENT           APARTMENT  479000.0
# 9081   20181127     8400        APARTMENT         FLAT_STUDIO  150000.0
# 9854   20291770     1730        APARTMENT           APARTMENT  309000.0
# 10607  10552073     8400        APARTMENT           APARTMENT  229000.0
# 12406  20311073     2000        APARTMENT           APARTMENT  299000.0
# 12816  20240469     1180        APARTMENT           APARTMENT  360000.0
# 12817  20240473     1180        APARTMENT           PENTHOUSE  869000.0
# 13310  20179990     8301        APARTMENT           APARTMENT  598000.0
# 14264  20220818     1348        APARTMENT           APARTMENT  440000.0
# 14363  20294279     2600        APARTMENT           APARTMENT  198000.0
#
#            Type of sale  Number of rooms  Living Area  Fully equipped kitchen  \
# 647    residential_sale                2         99.0                       1
# 776    residential_sale                3        250.0                       1
# 1180   residential_sale                1          NaN                      -1
# 1665   residential_sale                0         41.0                      -1
# 2163   residential_sale                3        170.0                      -1
# 2530   residential_sale                2         80.0                       1
# 2615   residential_sale                2        108.0                      -1
# 2627   residential_sale                1         38.0                       1
# 2708   residential_sale                1         95.0                       1
# 5041   residential_sale                1         51.0                       1
# 5059   residential_sale                2          NaN                      -1
# 5476   residential_sale                2         70.0                      -1
# 5545   residential_sale                0         36.0                       1
# 6526   residential_sale                0         33.0                       1
# 7454   residential_sale                2         80.0                      -1
# 7488   residential_sale                0         24.0                       1
# 8683   residential_sale                4        188.0                       1
# 8763   residential_sale                2         73.0                       1
# 8937   residential_sale                0          NaN                      -1
# 8938   residential_sale                2          NaN                      -1
# 9081   residential_sale                0         35.0                       1
# 9854   residential_sale                2         90.0                       1
# 10607  residential_sale                2         90.0                       1
# 12406  residential_sale                2         67.0                      -1
# 12816  residential_sale                1          NaN                      -1
# 12817  residential_sale                3          NaN                      -1
# 13310  residential_sale                2         96.0                       1
# 14264  residential_sale                2         93.0                       1
# 14363  residential_sale                1         55.0                       1
#
#       Furnished  ...  Terrace  Terrace area  Garden  Garden area  \
# 647        -1.0  ...       -1           NaN      -1          NaN
# 776        -1.0  ...       -1           NaN      -1          NaN
# 1180       -1.0  ...        1           1.0       1          1.0
# 1665        1.0  ...        1           2.0      -1          NaN
# 2163       -1.0  ...       -1           NaN       1        630.0
# 2530       -1.0  ...        1           NaN      -1          NaN
# 2615       -1.0  ...        1          10.0      -1          NaN
# 2627        1.0  ...        1           NaN      -1          NaN
# 2708       -1.0  ...        1          30.0      -1          NaN
# 5041        1.0  ...        1           2.0      -1          NaN
# 5059       -1.0  ...        1           1.0       1          1.0
# 5476       -1.0  ...        1           NaN      -1          NaN
# 5545       -1.0  ...       -1           NaN      -1          NaN
# 6526        0.0  ...       -1           NaN      -1          NaN
# 7454       -1.0  ...        1           4.0      -1          NaN
# 7488       -1.0  ...       -1           NaN      -1          NaN
# 8683       -1.0  ...       -1           NaN       1         27.0
# 8763       -1.0  ...        1           2.0      -1          NaN
# 8937       -1.0  ...        1           1.0       1          1.0
# 8938       -1.0  ...        1           1.0       1          1.0
# 9081       -1.0  ...       -1           NaN      -1          NaN
# 9854       -1.0  ...        1          18.0      -1          NaN
# 10607      -1.0  ...        1           9.0      -1          NaN
# 12406      -1.0  ...       -1           NaN      -1          NaN
# 12816      -1.0  ...        1           1.0       1          1.0
# 12817      -1.0  ...        1           1.0      -1          NaN
# 13310       0.0  ...        1           NaN      -1          NaN
# 14264       0.0  ...        1          16.0       1          1.0
# 14363      -1.0  ...        1          10.0      -1          NaN
#
#        Surface of the land  Surface area of the plot of land  \
# 647                    NaN                               NaN
# 776                    NaN                              59.0
# 1180                   1.0                               NaN
# 1665                   NaN                               NaN
# 2163                 630.0                             800.0
# 2530                   NaN                               NaN
# 2615                   NaN                               NaN
# 2627                   NaN                               NaN
# 2708                   NaN                               NaN
# 5041                   NaN                               NaN
# 5059                   1.0                               NaN
# 5476                   NaN                               NaN
# 5545                   NaN                               NaN
# 6526                   NaN                               NaN
# 7454                   NaN                               NaN
# 7488                   NaN                               NaN
# 8683                  27.0                             188.0
# 8763                   NaN                               NaN
# 8937                   1.0                               NaN
# 8938                   1.0                               NaN
# 9081                   NaN                               NaN
# 9854                   NaN                               NaN
# 10607                  NaN                               NaN
# 12406                  NaN                               NaN
# 12816                  1.0                               NaN
# 12817                  NaN                               NaN
# 13310                  NaN                               NaN
# 14264                  1.0                               NaN
# 14363                  NaN                               NaN
#
#        Number of facades  Swimming pool  State of the building  \
# 647                    1              0                 AS_NEW
# 776                    1              0             TO_RESTORE
# 1180                   1              0                 AS_NEW
# 1665                   1              0                 AS_NEW
# 2163                   1             -1            TO_RENOVATE
# 2530                   1              0                   GOOD
# 2615                   1             -1                 AS_NEW
# 2627                   1             -1         JUST_RENOVATED
# 2708                   1              0                   GOOD
# 5041                   1             -1                   GOOD
# 5059                   1              0                 AS_NEW
# 5476                   1             -1                   GOOD
# 5545                   1              0         JUST_RENOVATED
# 6526                   1             -1         JUST_RENOVATED
# 7454                   1              0         JUST_RENOVATED
# 7488                   1              0                 AS_NEW
# 8683                   1              0                 AS_NEW
# 8763                   1              0                   GOOD
# 8937                   1              0                 AS_NEW
# 8938                   1              0                 AS_NEW
# 9081                   1              0         JUST_RENOVATED
# 9854                   1              0                 AS_NEW
# 10607                  1              0                   GOOD
# 12406                  1              0                    NaN
# 12816                  1              0                 AS_NEW
# 12817                  1              0                 AS_NEW
# 13310                  1             -1         JUST_RENOVATED
# 14264                  1              0                 AS_NEW
# 14363                  1              0                   GOOD
#
#       Compound Listing
# 647             single
# 776             single
# 1180          compound
# 1665            single
# 2163            single
# 2530            single
# 2615            single
# 2627            single
# 2708            single
# 5041            single
# 5059          compound
# 5476            single
# 5545            single
# 6526            single
# 7454            single
# 7488            single
# 8683            single
# 8763            single
# 8937          compound
# 8938          compound
# 9081            single
# 9854            single
# 10607           single
# 12406           single
# 12816         compound
# 12817         compound
# 13310           single
# 14264           single
# 14363           single
#
# [29 rows x 21 columns]

# %%
plt.hist(data['Price'])
plt.title('Price')
plt.show()

# Remove >= 1_000_000 (676 rows)

# %%
data[data['Price'] >= 1_000_000] #Duplicate listings, drop one ; and almost all NaN, drop both
# Out:
#              id Locality Type of property Subtype of property      Price  \
# 12     20318961     1310        APARTMENT           APARTMENT  1875000.0
# 13     20318942     1310        APARTMENT           APARTMENT  2035000.0
# 142    20316318     8540            HOUSE               VILLA  1195000.0
# 164    20316000     1040        APARTMENT           PENTHOUSE  1150000.0
# 166    20307949     1150            HOUSE               HOUSE  1195000.0
# ...         ...      ...              ...                 ...        ...
# 15429  20261577     9630            HOUSE               VILLA  1100000.0
# 15432  20303201     4870            HOUSE     APARTMENT_BLOCK  1245000.0
# 15459  11446091     9185            HOUSE  MIXED_USE_BUILDING  1299000.0
# 15473  20261655     8300            HOUSE               VILLA  3395000.0
# 15514  20199264     1150            HOUSE               HOUSE  1045000.0
#
#            Type of sale  Number of rooms  Living Area  Fully equipped kitchen  \
# 12     residential_sale                3        260.0                       1
# 13     residential_sale                3        293.0                       1
# 142    residential_sale                5        500.0                       1
# 164    residential_sale                3        198.0                      -1
# 166    residential_sale                4        303.0                       1
# ...                 ...              ...          ...                     ...
# 15429  residential_sale                6        561.0                      -1
# 15432  residential_sale               12        814.0                       1
# 15459  residential_sale                3        220.0                       1
# 15473  residential_sale                4        244.0                      -1
# 15514  residential_sale                6        300.0                       1
#
#       Furnished  ...  Terrace  Terrace area  Garden  Garden area  \
# 12          0.0  ...        1          34.0      -1          NaN
# 13          0.0  ...        1          41.0      -1          NaN
# 142        -1.0  ...        1           NaN      -1          NaN
# 164        -1.0  ...        1          42.0      -1          NaN
# 166        -1.0  ...       -1           NaN       1        250.0
# ...         ...  ...      ...           ...     ...          ...
# 15429      -1.0  ...        1           NaN      -1          NaN
# 15432       0.0  ...        1           NaN      -1          NaN
# 15459      -1.0  ...        1           NaN      -1          NaN
# 15473       0.0  ...        1           NaN      -1          NaN
# 15514       0.0  ...        1          20.0       1        300.0
#
#        Surface of the land  Surface area of the plot of land  \
# 12                     NaN                               NaN
# 13                     NaN                               NaN
# 142                    NaN                            1560.0
# 164                    NaN                               NaN
# 166                  250.0                             428.0
# ...                    ...                               ...
# 15429                  NaN                            4925.0
# 15432                  NaN                           28600.0
# 15459                  NaN                           14569.0
# 15473                  NaN                             593.0
# 15514                300.0                             545.0
#
#        Number of facades  Swimming pool  State of the building  \
# 12                     3              0                 AS_NEW
# 13                    -1              0                 AS_NEW
# 142                    4              1                   GOOD
# 164                   -1             -1         JUST_RENOVATED
# 166                    3             -1         JUST_RENOVATED
# ...                  ...            ...                    ...
# 15429                 -1             -1                   GOOD
# 15432                  4              0                   GOOD
# 15459                 -1             -1                   GOOD
# 15473                 -1             -1                   GOOD
# 15514                  3              0                 AS_NEW
#
#       Compound Listing
# 12            compound
# 13            compound
# 142             single
# 164             single
# 166             single
# ...                ...
# 15429           single
# 15432           single
# 15459           single
# 15473           single
# 15514           single
#
# [676 rows x 21 columns]

# %%
plt.hist(data['Number of rooms'])
plt.title('Number of rooms')
plt.show()

# remove > 6? (156 rows)

# %%
data[data['Number of rooms'] > 6] # single castle, to drop
# Out:
#              id Locality Type of property   Subtype of property      Price  \
# 157    20313806     1030            HOUSE    MIXED_USE_BUILDING   770000.0
# 355    20192026     6890            HOUSE                 VILLA   360000.0
# 364    20316356     2830            HOUSE                 VILLA   749000.0
# 766    20148041     4000            HOUSE                 VILLA   595000.0
# 831    20286621     8740            HOUSE                 VILLA  1895000.0
# ...         ...      ...              ...                   ...        ...
# 15294  20122032     3020            HOUSE               MANSION   825000.0
# 15297  20304356     1473            HOUSE  EXCEPTIONAL_PROPERTY   950000.0
# 15331  11419026     6800            HOUSE                 HOUSE   339000.0
# 15432  20303201     4870            HOUSE       APARTMENT_BLOCK  1245000.0
# 15490  11376970     9310            HOUSE    MIXED_USE_BUILDING   395000.0
#
#            Type of sale  Number of rooms  Living Area  Fully equipped kitchen  \
# 157    residential_sale                7        260.0                      -1
# 355    residential_sale                7        226.0                       1
# 364    residential_sale                8        384.0                      -1
# 766    residential_sale                7        455.0                       1
# 831    residential_sale                8        334.0                      -1
# ...                 ...              ...          ...                     ...
# 15294  residential_sale               11        669.0                       1
# 15297  residential_sale                7        382.0                      -1
# 15331  residential_sale                8        120.0                       1
# 15432  residential_sale               12        814.0                       1
# 15490  residential_sale                7        431.0                      -1
#
#       Furnished  ...  Terrace  Terrace area  Garden  Garden area  \
# 157         0.0  ...       -1           NaN      -1          NaN
# 355        -1.0  ...        1           NaN       1        500.0
# 364        -1.0  ...       -1           NaN      -1          NaN
# 766        -1.0  ...        1          28.0       1       3100.0
# 831        -1.0  ...        1           NaN      -1          NaN
# ...         ...  ...      ...           ...     ...          ...
# 15294      -1.0  ...        1           NaN      -1          NaN
# 15297      -1.0  ...       -1           NaN      -1          NaN
# 15331       1.0  ...        1          40.0       1        630.0
# 15432       0.0  ...        1           NaN      -1          NaN
# 15490       0.0  ...        1          25.0       1        295.0
#
#        Surface of the land  Surface area of the plot of land  \
# 157                    NaN                             110.0
# 355                  500.0                            2066.0
# 364                    NaN                             923.0
# 766                 3100.0                            3333.0
# 831                    NaN                           18262.0
# ...                    ...                               ...
# 15294                  NaN                             799.0
# 15297                  NaN                           15400.0
# 15331                630.0                             770.0
# 15432                  NaN                           28600.0
# 15490                295.0                             565.0
#
#        Number of facades  Swimming pool  State of the building  \
# 157                    2              0                   GOOD
# 355                    4             -1          TO_BE_DONE_UP
# 364                    4              0                   GOOD
# 766                    4             -1            TO_RENOVATE
# 831                    4             -1                   GOOD
# ...                  ...            ...                    ...
# 15294                  2             -1          TO_BE_DONE_UP
# 15297                  4              1          TO_BE_DONE_UP
# 15331                  3              0                   GOOD
# 15432                  4              0                   GOOD
# 15490                  2             -1          TO_BE_DONE_UP
#
#       Compound Listing
# 157             single
# 355             single
# 364             single
# 766             single
# 831             single
# ...                ...
# 15294           single
# 15297           single
# 15331           single
# 15432           single
# 15490           single
#
# [156 rows x 21 columns]

# %%
plt.hist(data['Living Area'])
plt.title('Living Area')
plt.show()

# Remove >= 500 (183 rows)

# %%
data[data['Living Area'] >= 500] # A farmhouse
# Out:
#              id Locality Type of property Subtype of property      Price  \
# 142    20316318     8540            HOUSE               VILLA  1195000.0
# 306    20263033     1050            HOUSE               HOUSE  1995000.0
# 643    20314356     1000            HOUSE     APARTMENT_BLOCK   675000.0
# 661    20292008     8420            HOUSE               HOUSE   645000.0
# 717    20310041     2860            HOUSE               VILLA  1490000.0
# ...         ...      ...              ...                 ...        ...
# 15262  20264615     1050            HOUSE               HOUSE  1995000.0
# 15294  20122032     3020            HOUSE             MANSION   825000.0
# 15367  20272126     2950            HOUSE               VILLA  2300000.0
# 15429  20261577     9630            HOUSE               VILLA  1100000.0
# 15432  20303201     4870            HOUSE     APARTMENT_BLOCK  1245000.0
#
#            Type of sale  Number of rooms  Living Area  Fully equipped kitchen  \
# 142    residential_sale                5        500.0                       1
# 306    residential_sale                4        544.0                       1
# 643    residential_sale                0       1042.0                      -1
# 661    residential_sale                4        568.0                      -1
# 717    residential_sale                5        564.0                       1
# ...                 ...              ...          ...                     ...
# 15262  residential_sale                4        544.0                       1
# 15294  residential_sale               11        669.0                       1
# 15367  residential_sale                5        627.0                       1
# 15429  residential_sale                6        561.0                      -1
# 15432  residential_sale               12        814.0                       1
#
#       Furnished  ...  Terrace  Terrace area  Garden  Garden area  \
# 142        -1.0  ...        1           NaN      -1          NaN
# 306         0.0  ...        1          90.0       1        250.0
# 643         0.0  ...       -1           NaN      -1          NaN
# 661        -1.0  ...       -1           NaN      -1          NaN
# 717        -1.0  ...        1           NaN      -1          NaN
# ...         ...  ...      ...           ...     ...          ...
# 15262       0.0  ...        1           NaN       1        230.0
# 15294      -1.0  ...        1           NaN      -1          NaN
# 15367       0.0  ...        1           NaN      -1          NaN
# 15429      -1.0  ...        1           NaN      -1          NaN
# 15432       0.0  ...        1           NaN      -1          NaN
#
#        Surface of the land  Surface area of the plot of land  \
# 142                    NaN                            1560.0
# 306                  250.0                             666.0
# 643                    NaN                             971.0
# 661                    NaN                            2263.0
# 717                    NaN                            1610.0
# ...                    ...                               ...
# 15262                230.0                             405.0
# 15294                  NaN                             799.0
# 15367                  NaN                            4022.0
# 15429                  NaN                            4925.0
# 15432                  NaN                           28600.0
#
#        Number of facades  Swimming pool  State of the building  \
# 142                    4              1                   GOOD
# 306                    2              0                 AS_NEW
# 643                    2              0                    NaN
# 661                   -1             -1                   GOOD
# 717                    4              1                 AS_NEW
# ...                  ...            ...                    ...
# 15262                  2             -1                 AS_NEW
# 15294                  2             -1          TO_BE_DONE_UP
# 15367                  4              1                 AS_NEW
# 15429                 -1             -1                   GOOD
# 15432                  4              0                   GOOD
#
#       Compound Listing
# 142             single
# 306             single
# 643             single
# 661             single
# 717             single
# ...                ...
# 15262           single
# 15294           single
# 15367           single
# 15429           single
# 15432           single
#
# [183 rows x 21 columns]

# %%
data.groupby("Type of property").count()
# Out:
#                      id  Locality  Subtype of property  Price  Type of sale  \
# Type of property
# APARTMENT         10694     10694                10694  10694         10694
# HOUSE              4822      4822                 4822   4822          4822
#
#                   Number of rooms  Living Area  Fully equipped kitchen  \
# Type of property
# APARTMENT                   10694        10529                    7328
# HOUSE                        4822         4766                    3585
#
#                   Furnished  Fireplace  Terrace  Terrace area  Garden  \
# Type of property
# APARTMENT              5016      10694     8623          7329     795
# HOUSE                  2266       4822     3378          1880    2187
#
#                   Garden area  Surface of the land  \
# Type of property
# APARTMENT                 795                  795
# HOUSE                    2187                 2187
#
#                   Surface area of the plot of land  Number of facades  \
# Type of property
# APARTMENT                                        0               6237
# HOUSE                                         4822               3874
#
#                   Swimming pool  State of the building  Compound Listing
# Type of property
# APARTMENT                  3808                   7432             10694
# HOUSE                      2007                   4473              4822

# %%
import seaborn as sns

# %%
# Heatmap correlation matrix of the continuous data + response variable

corr_matrix = data[['Price', 'Number of rooms', 'Living Area', 'Terrace area', 'Garden area', 'Surface of the land', 'Surface area of the plot of land', 'Number of facades']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
# Out:
# <Axes: >

# %%
data_modified.boxplot(column= 'Price', by='Garden')
# Out:
# <Axes: title={'center': 'Price'}, xlabel='Garden'>

# %%
data_modified = data[['Garden', 'Price', 'Type of property']]
data_modified['Garden'] = data_modified['Garden'].fillna(0)
# Out:
# C:\Users\kvnpo\AppData\Local\Temp\ipykernel_3356\2339460935.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_modified['Garden'] = data_modified['Garden'].fillna(0)

# %%
data_modified[data_modified['Garden'] == 1.0]['Type of property'].value_counts()
# Out:
# Type of property
# HOUSE        1927
# APARTMENT     618
# Name: count, dtype: int64

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca_components = pca.fit_transform(data.select_dtypes(include=['float64', 'int64']))
sns.scatterplot(x=pca_components[:, 0], y=pca_components[:, 1], hue=df['response_variable'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[115], line 3
#       1 from sklearn.decomposition import PCA
#       2 pca = PCA(n_components=2)
# ----> 3 pca_components = pca.fit_transform(data.select_dtypes(include=['float64', 'int64']))
#       4 sns.scatterplot(x=pca_components[:, 0], y=pca_components[:, 1], hue=df['response_variable'])
#
# File c:\Users\kvnpo\anaconda3\envs\ImmoEliza\Lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
#     319         )
#
# File c:\Users\kvnpo\anaconda3\envs\ImmoEliza\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\kvnpo\anaconda3\envs\ImmoEliza\Lib\site-packages\sklearn\decomposition\_pca.py:474, in PCA.fit_transform(self, X, y)
#     451 @_fit_context(prefer_skip_nested_validation=True)
#     452 def fit_transform(self, X, y=None):
#     453     """Fit the model with X and apply the dimensionality reduction on X.
#     454
#     455     Parameters
#    (...)
#     472     C-ordered array, use 'np.ascontiguousarray'.
#     473     """
# --> 474     U, S, _, X, x_is_centered, xp = self._fit(X)
#     475     if U is not None:
#     476         U = U[:, : self.n_components_]
#
# File c:\Users\kvnpo\anaconda3\envs\ImmoEliza\Lib\site-packages\sklearn\decomposition\_pca.py:511, in PCA._fit(self, X)
#     501     raise ValueError(
#     502         "PCA with svd_solver='arpack' is not supported for Array API inputs."
#     503     )
#     505 # Validate the data, without ever forcing a copy as any solver that
#     506 # supports sparse input data and the `covariance_eigh` solver are
#     507 # written in a way to avoid the need for any inplace modification of
#     508 # the input data contrary to the other solvers.
#     509 # The copy will happen
#     510 # later, only if needed, once the solver negotiation below is done.
# --> 511 X = self._validate_data(
#     512     X,
#     513     dtype=[xp.float64, xp.float32],
#     514     force_writeable=True,
#     515     accept_sparse=("csr", "csc"),
#     516     ensure_2d=True,
#     517     copy=False,
#     518 )
#     519 self._fit_svd_solver = self.svd_solver
#     520 if self._fit_svd_solver == "auto" and issparse(X):
#
# File c:\Users\kvnpo\anaconda3\envs\ImmoEliza\Lib\site-packages\sklearn\base.py:633, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     631         out = X, y
#     632 elif not no_val_X and no_val_y:
# --> 633     out = check_array(X, input_name="X", **check_params)
#     634 elif no_val_X and not no_val_y:
#     635     out = _check_y(y, **check_params)
#
# File c:\Users\kvnpo\anaconda3\envs\ImmoEliza\Lib\site-packages\sklearn\utils\validation.py:1064, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1058     raise ValueError(
#    1059         "Found array with dim %d. %s expected <= 2."
#    1060         % (array.ndim, estimator_name)
#    1061     )
#    1063 if force_all_finite:
# -> 1064     _assert_all_finite(
#    1065         array,
#    1066         input_name=input_name,
#    1067         estimator_name=estimator_name,
#    1068         allow_nan=force_all_finite == "allow-nan",
#    1069     )
#    1071 if copy:
#    1072     if _is_numpy_namespace(xp):
#    1073         # only make a copy if `array` and `array_orig` may share memory`
#
# File c:\Users\kvnpo\anaconda3\envs\ImmoEliza\Lib\site-packages\sklearn\utils\validation.py:123, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     120 if first_pass_isfinite:
#     121     return
# --> 123 _assert_all_finite_element_wise(
#     124     X,
#     125     xp=xp,
#     126     allow_nan=allow_nan,
#     127     msg_dtype=msg_dtype,
#     128     estimator_name=estimator_name,
#     129     input_name=input_name,
#     130 )
#
# File c:\Users\kvnpo\anaconda3\envs\ImmoEliza\Lib\site-packages\sklearn\utils\validation.py:172, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     155 if estimator_name and input_name == "X" and has_nan_error:
#     156     # Improve the error message on how to handle missing values in
#     157     # scikit-learn.
#     158     msg_err += (
#     159         f"\n{estimator_name} does not accept missing values"
#     160         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     170         "#estimators-that-handle-nan-values"
#     171     )
# --> 172 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# PCA does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
